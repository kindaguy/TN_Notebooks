# %%
using Pkg
Pkg.activate("..")
using ITensors
# Out:
#   Activating project at `~/Library/CloudStorage/OneDrive-UniversitàdegliStudidiMilano/Work/Workspace/Unimi/Corsi/TN_Ulm/Materiale_dispense/TN_Notebooks`

# %%
i = Index(2, "i")
j = Index(2, "j")
# Out:
# (dim=2|id=944|"j")

# %%
comb = combiner(i, j)
combidx = combinedind(comb)
# Out:
# (dim=4|id=540|"CMB,Link")

# %%
comb
# Out:
# ITensor ord=3 (dim=4|id=540|"CMB,Link") (dim=2|id=745|"i") (dim=2|id=944|"j")
# NDTensors.Combiner
