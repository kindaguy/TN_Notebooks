# %%
using Pkg
Pkg.activate("..")
using Random
using DelimitedFiles
# Out:
#   Activating project at `~/Library/CloudStorage/OneDrive-UniversitàdegliStudidiMilano/Work/Workspace/Unimi/Corsi/TN_Ulm/Materiale_dispense/TN_Notebooks`

# %%
rng = MersenneTwister(1234)
nn = 20
noise = randn(rng, Float64, nn) .* 0.5
# Out:
# 20-element Vector{Float64}:
#  -0.40597522155704313
#   0.06311886533873023
#  -0.027391856370233322
#   0.05164581701670314
#  -0.10602566017476933
#   1.2781192267984953
#   0.0052442729244930935
#  -0.34985879485059296
#  -0.41641137909703224
#  -0.7289809351210947
#  -0.43261784646346463
#   0.3845239658146329
#   0.7583440005193743
#  -0.8973170368882014
#  -0.49283562442386164
#   0.23709795779942733
#  -0.5493136725543539
#   0.3387355784065831
#  -0.6609103668676712
#   0.8886171325212545

# %%
writedlm("onSiteEnergies.dat", noise)

# %%
a= readdlm("onSiteEnergies.dat")
# Out:
# 20×1 Matrix{Float64}:
#  -0.40597522155704313
#   0.06311886533873023
#  -0.027391856370233322
#   0.05164581701670314
#  -0.10602566017476933
#   1.2781192267984953
#   0.0052442729244930935
#  -0.34985879485059296
#  -0.41641137909703224
#  -0.7289809351210947
#  -0.43261784646346463
#   0.3845239658146329
#   0.7583440005193743
#  -0.8973170368882014
#  -0.49283562442386164
#   0.23709795779942733
#  -0.5493136725543539
#   0.3387355784065831
#  -0.6609103668676712
#   0.8886171325212545
