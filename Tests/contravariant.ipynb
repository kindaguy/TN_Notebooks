# %% [markdown]
# # Covariant and Contravariant Tensors

# %%
using Pkg
Pkg.activate("..")
using ITensors
# Out:
#   Activating project at `~/Work/Workspace/Unimi/Corsi/TN_Ulm/Materiale_dispense/Notebooks`

# %%
i = Index(3, "i")
j = Index(4, "j")
A = random_itensor(ComplexF64, i,j)
B = random_itensor(ComplexF64, i,j)
# Out:
# ITensor ord=2 (dim=3|id=191|"i") (dim=4|id=792|"j")
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}

# %%
A*B
# Out:
# ITensor ord=0
# NDTensors.Dense{ComplexF64, Vector{ComplexF64}}

# %%
appo = Matrix(A,i,j)
# Out:
# 3×4 Matrix{ComplexF64}:
#  -0.899234+0.894705im  -0.134122-1.02106im   …  -0.798856-0.17562im
#   -1.29597-1.01818im     0.84068-0.189838im       1.50334-0.206072im
#   -0.11608+0.413441im  -0.543802-0.693884im     -0.244498+0.869249im

# %%
@show(appo)
# Out:
# appo = ComplexF64[-0.8992342827175387 + 0.8947047125908036im -0.13412226586619944 - 1.021060859704085im -0.5327271544920333 + 0.013503268271125189im -0.7988564118528747 - 0.17562025854894847im; -1.2959740565370477 - 1.018182438267512im 0.8406795020603366 - 0.18983785023923927im -1.1353631824923842 + 0.19762378991615445im 1.5033384278308752 - 0.20607175441986975im; -0.11608020213851758 + 0.4134413084706353im -0.5438018496493666 - 0.6938840558724739im -0.6351871447794727 - 0.7080906544037323im -0.24449798467659645 + 0.8692485075399412im]
# 3×4 Matrix{ComplexF64}:
#  -0.899234+0.894705im  -0.134122-1.02106im   …  -0.798856-0.17562im
#   -1.29597-1.01818im     0.84068-0.189838im       1.50334-0.206072im
#   -0.11608+0.413441im  -0.543802-0.693884im     -0.244498+0.869249im
